# │   34   10-D      BANK 2019-BNK21                               1787490   2023-12-29    0001888524-23-018044     │
# │   35   10-D      BANK 2019-BNK23                               1792414   2023-12-29    0001888524-23-018078     │
# │   36   10-D      BANK 2019-BNK24                               1793165   2023-12-29    0001888524-23-018046     │
# │   37   10-D      BANK 2020-BNK26                               1803308   2023-12-29    0001888524-23-018105     │
# │   38   10-D      BANK 2020-BNK27                               1806944   2023-12-29    0001888524-23-018042     │
# │   39   10-D      BANK 2020-BNK29                               1830315   2023-12-29    0001888524-23-018082     │
# │   40   10-D      BANK 2020-BNK30                               1832874   2023-12-29    0001888524-23-018026     │
# │   41   10-D      BANK 2021-BNK32                               1848411   2023-12-29    0001888524-23-018101     │
# │   42   10-D      BANK 2021-BNK33                               1858865   2023-12-29    0001888524-23-018058     │
# │   43   10-D      BANK 2021-BNK35                               1872347   2023-12-29    0001888524-23-018142     │
# │   44   10-D      BANK 2021-BNK36                               1880921   2023-12-29    0001888524-23-018209     │
# │   45   10-D      BANK 2021-BNK38                               1895567   2023-12-29    0001888524-23-018070     │
# │   46   10-D      BANK 2022-BNK39                               1902565   2023-12-29    0001888524-23-018179     │
# │   47   10-D      BANK 2022-BNK41                               1920442   2023-12-29    0001888524-23-018095     │
# │   48   10-D      BANK 2022-BNK42                               1926900   2023-12-29    0001888524-23-018188     │
# │   49   10-D      BANK 2022-BNK44                               1950141   2023-12-29    0001888524-23-018107     │
# │                                                                                                                 │
# │ Showing 50 of 1,158,643 filings                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
# ticker
company = Company("AAPL")

# GET data
filing_new_10k = company.get_filings(form="10-K").latest(1)
filing_new_8k = company.get_filings(form="8-K").latest(1)
filing_new_14a = company.get_filings(form="DEF 14A").latest(1)

# %%
#### view output
filing_new_14a
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────── Apple Inc. [320193] DEF 14A 📄 ─────────────────────────────────────────╮
# │ ╭──────────────────────┬────────────╮                                                                           │
# │ │ 0001308179-24-000010 │ 2024-01-11 │                                                                           │
# │ ╰──────────────────────┴────────────╯                                                                           │
# │ ╭───────────────────────────────────────────────────────────────────────────────────────────╮                   │
# │ │ Links: 🏠 Homepage 📄 Primary Document 📜 Full Submission Text                            │                   │
# │ ├───────────────────────────────────────────────────────────────────────────────────────────┤                   │
# │ │ 🏠 https://sec.gov/Archives/edgar/data/320193/0001308179-24-000010-index.html             │                   │
# │ │ 📄 https://sec.gov/Archives/edgar/data/320193/000130817924000010/laapl2024_def14a.htm     │                   │
# │ │ 📜 https://sec.gov/Archives/edgar/data/320193/000130817924000010/0001308179-24-000010.txt │                   │
# │ ╰───────────────────────────────────────────────────────────────────────────────────────────╯                   │
# ╰─────────────────────────────────── Form DEF 14A: Definitive proxy statement ────────────────────────────────────╯

# %%
set_identity("Matt Sutherland sudz4@proton.me")
# Run the download function

# %%
# List of stock tickers
tickers = ["AAPL", "MSFT", "GOOGL", "AMZN"]

# Function to download DEF 14A filings for a list of tickers
def download_def_14a_filings(tickers):
    for ticker in tickers:
        company = Company(ticker)
        filing = company.get_filings(form="DEF 14A").latest(1)
        # Save the filing as text
        filing_text = filing.text()
        with open(f"{ticker}_DEF14A.txt", "w") as f:
            f.write(filing_text)
        print(f"Downloaded DEF 14A for {ticker}")

# Set your identity
set_identity("Matt Sutherland sudz4@proton.me")

# Run the download function
download_def_14a_filings(tickers)
# Out:
# [20:22:29] INFO     Identity of the Edgar REST client set to [Matt Sutherland sudz4@proton.me]          ]8;id=723256;file:///Users/sudz4/Desktop/GHGAGW/edgartools/edgar/core.py\core.py]8;;\:]8;id=86225;file:///Users/sudz4/Desktop/GHGAGW/edgartools/edgar/core.py#153\153]8;;\
# Downloaded DEF 14A for AAPL
# Downloaded DEF 14A for MSFT
# Downloaded DEF 14A for GOOGL
# Downloaded DEF 14A for AMZN
